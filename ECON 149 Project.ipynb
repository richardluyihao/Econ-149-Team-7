# %% [raw]
# Project Overview:
#
# The purpose of this project is to see the relationship between GDP and interest rate for the entire U.S. The macroeconomics theory states that there is a negative relation between interest rate and GDP. In this project, we have time series data of interest rate and GDP for the U.S. We shall use linear regression analysis to verify this theory.
#
# Project Structure:
#
# The project will start with a data report.
#
# The second part of the project is summary statistics about GDP and interest rate trends and provide visualizations of these statistics to help further illustrate the project.
# The third part is a linear regression used to verify a certain theory.
# In the end, there will be a discussion of the results and how it follows or goes against previous scholarship.
#
# Data Report:
#
# The data for this project comes from the Federal Reserve Economic Data website (FRED). The data can be accessed at https://fred.stlouisfed.org.
#
# Key Variables:
#
# The four key variables in this project are GDP, potential GDP, and federal funds rate.
# The federal funds rate is the interest rate at which depository institutions trade federal funds (balances held at Federal Reserve Banks) with each other overnight. When a depository institution has surplus balances in its reserve account, it lends to other banks in need of larger balances. In simpler terms, a bank with excess cash, which is often referred to as liquidity, will lend to another bank that needs to quickly raise liquidity. The federal funds rate is the central interest rate in the U.S. financial market. It influences other interest rates such as the prime rate, which is the rate banks charge their customers with higher credit ratings. Additionally, the federal funds rate indirectly influences longer-term interest rates such as mortgages, loans, and savings, all of which are very important to consumer wealth and confidence.Therefore, we choose federal funds rate to reperesent the interest rate.
# Real GDP is the inflation adjusted value of the goods and services produced by labor and property located in the United States.
# Real potential GDP is the CBO’s estimate of the output the economy would produce with a high rate of use of its capital and labor resources. The data is adjusted to remove the effects of inflation.
# A derivative variable short-run output is calculated by substract potential GDP from GDP.

# %%
#Key Imports
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import statsmodels.api as sm
from statsmodels.iolib.summary2 import summary_col

# %%
#Access GDP
url_1 = 'https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=GDPC1&scale=left&cosd=1947-01-01&coed=2020-07-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2020-12-08&revision_date=2020-12-08&nd=1947-01-01'
data_1 = pd.read_csv(url_1, parse_dates=True)
data_1.head()
# Out:
#          DATE     GDPC1
# 0  1947-01-01  2033.061
# 1  1947-04-01  2027.639
# 2  1947-07-01  2023.452
# 3  1947-10-01  2055.103
# 4  1948-01-01  2086.017

# %%
data_1.columns=['DATE','GDP']
data_1.head()
# Out:
#          DATE       GDP
# 0  1947-01-01  2033.061
# 1  1947-04-01  2027.639
# 2  1947-07-01  2023.452
# 3  1947-10-01  2055.103
# 4  1948-01-01  2086.017

# %%
#Summary Statistics for GDP
data_1.describe()
# Out:
#                 GDP
# count    295.000000
# mean    8783.982559
# std     5222.908670
# min     2023.452000
# 25%     4159.357500
# 50%     7339.893000
# 75%    13437.577000
# max    19253.959000

# %%
#Graphing the GDP
data1=data_1.set_index('DATE')
ax = data1['1947':'2020'].plot(title='GDP', legend=False, figsize=(12,6))
ax.set_xlabel('year', fontsize=12)
ax.set_ylabel('Billions of 2012 Dollars', fontsize=12)
plt.show()

# %%
#Access Federal Funds Rate 
url_2 = 'https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=DFF&scale=left&cosd=1954-07-01&coed=2020-12-04&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2020-12-08&revision_date=2020-12-08&nd=1954-07-01'
data_2 = pd.read_csv(url_2, parse_dates=True)
data_2.head()
# Out:
#          DATE       DFF
# 0  1954-07-01  1.028478
# 1  1954-10-01  0.988370
# 2  1955-01-01  1.345000
# 3  1955-04-01  1.501099
# 4  1955-07-01  1.936522

# %%
data_2.columns=['DATE','Federal Funds Rate']
data_2.head()
data_2 = pd.DataFrame(data_2)
data_2['Federal Funds Rate'] = pd.to_numeric(data_2['Federal Funds Rate'], errors='coerce')

# %%
#Summary Statistics for Federal Funds Rate
data_2.describe()
# Out:
#        Federal Funds Rate
# count          266.000000
# mean             4.707149
# std              3.589120
# min              0.058791
# 25%              1.942962
# 50%              4.390407
# 75%              6.463780
# max             17.786923

# %%
#Graphing the Federal Funds Rate
data2=data_2.set_index('DATE')
ax = data2['1954':'2020'].plot(title='Federal Funds Rate', legend=False, figsize=(12,6))
ax.set_xlabel('year', fontsize=12)
ax.set_ylabel('%', fontsize=12)
plt.show()

# %%
#Access Potential GDP 
url_3 = 'https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=GDPPOT&scale=left&cosd=1949-01-01&coed=2030-10-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2020-12-08&revision_date=2020-12-08&nd=1949-01-01'
data_3 = pd.read_csv(url_3, parse_dates=True)
data_3.head()
# Out:
#          DATE       GDPPOT
# 0  1949-01-01  2103.613427
# 1  1949-04-01  2131.592513
# 2  1949-07-01  2160.755198
# 3  1949-10-01  2188.685100
# 4  1950-01-01  2218.331859

# %%
data_3.columns=['DATE', 'Potential GDP']
data_3.head()
# Out:
#          DATE  Potential GDP
# 0  1949-01-01    2103.613427
# 1  1949-04-01    2131.592513
# 2  1949-07-01    2160.755198
# 3  1949-10-01    2188.685100
# 4  1950-01-01    2218.331859

# %%
#Summary Statistics for Potential GDP
data_3.describe()
# Out:
#        Potential GDP
# count     328.000000
# mean    10579.926408
# std      6361.190529
# min      2103.613427
# 25%      4862.484308
# 50%      9345.272057
# 75%     16302.367260
# max     23047.200000

# %%
#Graphing the Potential GDP
data3=data_3.set_index('DATE')
ax = data3['1949':'2020'].plot(title='Potential GDP', legend=False, figsize=(12,6))
ax.set_xlabel('year', fontsize=12)
ax.set_ylabel('Billions of 2012 Dollars', fontsize=12)
plt.show()

# %%
data_merge['ShortRun Output']=(data_merge['GDP']-data_merge['Potential GDP'])/data_merge['Potential GDP']

# %%
data_merge.head()
# Out:
#          DATE       GDP  Potential GDP  ShortRun Output
# 0  1949-01-01  2105.562    2103.613427         0.000926
# 1  1949-04-01  2098.380    2131.592513        -0.015581
# 2  1949-07-01  2120.044    2160.755198        -0.018841
# 3  1949-10-01  2102.251    2188.685100        -0.039491
# 4  1950-01-01  2184.872    2218.331859        -0.015083

# %%
data_merge['ShortRun Output'].describe()
# Out:
# count    287.000000
# mean      -0.006431
# std        0.024118
# min       -0.099005
# 25%       -0.019452
# 50%       -0.007766
# 75%        0.010029
# max        0.054727
# Name: ShortRun Output, dtype: float64

# %%
#Graphing the ShortRun Output
data_merge1=data_merge[['DATE','ShortRun Output']]
data_merge1=data_merge1.set_index('DATE')
data_merge1['ShortRun Output']=data_merge1['ShortRun Output']*100
ax = data_merge1['1949':'2020'].plot(title='ShortRun Output', legend=False, figsize=(12,6))
ax.set_xlabel('year', fontsize=12)
ax.set_ylabel('%', fontsize=12)
plt.show()

# %%
data_merge_2=pd.merge(data_merge, data_2, how='inner', on='DATE', left_on=None, right_on=None,
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
data_merge_2.head()
# Out:
#          DATE       GDP  Potential GDP  ShortRun Output  Federal Funds Rate
# 0  1954-07-01  2682.601    2729.095299        -0.017037            1.028478
# 1  1954-10-01  2735.091    2746.324561        -0.004090            0.988370
# 2  1955-01-01  2813.212    2763.000715         0.018173            1.345000
# 3  1955-04-01  2858.988    2780.799016         0.028117            1.501099
# 4  1955-07-01  2897.598    2798.332798         0.035473            1.936522

# %%
data_merge_2.fillna(0)
# Out:
#            DATE        GDP  Potential GDP  ShortRun Output  Federal Funds Rate
# 0    1954-07-01   2682.601    2729.095299        -0.017037            1.028478
# 1    1954-10-01   2735.091    2746.324561        -0.004090            0.988370
# 2    1955-01-01   2813.212    2763.000715         0.018173            1.345000
# 3    1955-04-01   2858.988    2780.799016         0.028117            1.501099
# 4    1955-07-01   2897.598    2798.332798         0.035473            1.936522
# 5    1955-10-01   2914.993    2816.519739         0.034963            2.359022
# 6    1956-01-01   2903.671    2835.001431         0.024222            2.482308
# 7    1956-04-01   2927.665    2853.303309         0.026062            2.694505
# 8    1956-07-01   2925.035    2872.488725         0.018293            2.808587
# 9    1956-10-01   2973.179    2892.541414         0.027878            2.929891
# 10   1957-01-01   2992.219    2914.103623         0.026806            2.933000
# ...

# %%
from numpy.polynomial.polynomial import polyfit
fig,ax=plt.subplots()
ax.plot(data_merge_2['Federal Funds Rate'],data_merge_2['ShortRun Output'],'b*')
ax.set_xlabel("Federal Funds Rate")
ax.set_ylabel("ShortRun Output")
b,m=polyfit(data_merge_2['Federal Funds Rate'],data_merge_2['ShortRun Output'],1)
ax.plot(data_merge_2['Federal Funds Rate'],b+m*data_merge_2['Federal Funds Rate'],'-')

# %%
from scipy.stats import linregress
gradient, intercept, r_value, p_value, std_err = linregress(data_merge_2['ShortRun Output'], data_merge_2['Federal Funds Rate'])
gradient, intercept, r_value,std_err, p_value
# Out:
# (17.949036804110914,
#  4.865331279031911,
#  0.11838872967513707,
#  9.282989750987825,
#  0.05424273462548958)

# %%
#Regression 
data_merge_2['const'] = 1
reg1 = sm.OLS(endog=data_merge_2['Federal Funds Rate'], exog=data_merge_2[['const', 'ShortRun Output']], \
    missing='drop')
type(reg1)
# Out:
# statsmodels.regression.linear_model.OLS

# %%
results = reg1.fit()
type(results)
# Out:
# statsmodels.regression.linear_model.RegressionResultsWrapper

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     Federal Funds Rate   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     3.739
# Date:                Tue, 08 Dec 2020   Prob (F-statistic):             0.0542
# Time:                        10:19:41   Log-Likelihood:                -711.96
# No. Observations:                 265   AIC:                             1428.
# Df Residuals:                     263   BIC:                             1435.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               4.8653      0.231     21.076      0.000       4.411       5.320
# ...

# %% [raw]
# Discussion: the theory about interest rate and GDP shot-run output is the IS curve. And it states that higher interest rate will decrease short-run output as higher interest inhibits investment. However, our regression model showed quite the opposite with a relatively low p-value (0.0542). My guess is that there exists a reversed causality, i.e., federal funds rate is adjusted to control short-run output in a certain range, and it always react after the observed short-run output. Thus, the time delay or misalignment causes an outcome that is opposite to the theory.
